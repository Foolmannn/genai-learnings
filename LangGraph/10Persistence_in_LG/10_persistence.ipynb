# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm =  ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': [{'type': 'text',
#    'text': 'Why does pizza only come in a square box?\n\nBecause it’s round, you eat it in triangles, and it’s served in a square box. \n\nIt’s the only food that’s constantly trying to confuse you!',
#    'extras': {'signature': 'EnEKbwERTTIPQCrMxpImwVuzVWDgsr0lqomrbNkxIMDFknWKUaRJNK9djM+XH3D/Zy1RVz+rhyX9tXtuCekT4xKwVW9Yh8x1lMwaAyrKaApjKWK3x5o/W7s9ZwrCvkmwpPAAYZdT1/kYeqA+IvSSKw+YbA=='}}],
#  'explanation': [{'type': 'text',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': [{'type': 'text', 'text': 'Why does pizza only come in a square box?\n\nBecause it’s round, you eat it in triangles, and it’s served in a square box. \n\nIt’s the only food that’s constantly trying to confuse you!', 'extras': {'signature': 'EnEKbwERTTIPQCrMxpImwVuzVWDgsr0lqomrbNkxIMDFknWKUaRJNK9djM+XH3D/Zy1RVz+rhyX9tXtuCekT4xKwVW9Yh8x1lMwaAyrKaApjKWK3x5o/W7s9ZwrCvkmwpPAAYZdT1/kYeqA+IvSSKw+YbA=='}}], 'explanation': [{'type': 'text', 'text': 'This joke relies on the **irony and absurdity of geometric shapes** that we encounter in everyday life, specifically regarding how pizza is manufactured, packaged, and consumed.\n\nHere is the breakdown of why it is considered funny:\n\n### 1. The Geometric Incongruity\nThe humor stems from the "non-matching" shapes involved in the pizza experience:\n*   **It’s round:** Pizza is almost always baked as a circle.\n*   **You eat it in triangles:** Because of the circular shape, it is traditionally slice
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': [{'type': 'text', 'text': 'Why does pizza only come in a square box?\n\nBecause it’s round, you eat it in triangles, and it’s served in a square box. \n\nIt’s the only food that’s constantly trying to confuse you!', 'extras': {'signature': 'EnEKbwERTTIPQCrMxpImwVuzVWDgsr0lqomrbNkxIMDFknWKUaRJNK9djM+XH3D/Zy1RVz+rhyX9tXtuCekT4xKwVW9Yh8x1lMwaAyrKaApjKWK3x5o/W7s9ZwrCvkmwpPAAYZdT1/kYeqA+IvSSKw+YbA=='}}], 'explanation': [{'type': 'text', 'text': 'This joke relies on the **irony and absurdity of geometric shapes** that we encounter in everyday life, specifically regarding how pizza is manufactured, packaged, and consumed.\n\nHere is the breakdown of why it is considered funny:\n\n### 1. The Geometric Incongruity\nThe humor stems from the "non-matching" shapes involved in the pizza experience:\n*   **It’s round:** Pizza is almost always baked as a circle.\n*   **You eat it in triangles:** Because of the circular shape, it is traditionally slic
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': [{'type': 'text',
#    'text': 'Why did the pasta go to the doctor?\n\nBecause it was feeling **cannelloni**.',
#    'extras': {'signature': 'EnEKbwERTTIPQzzKGrU5a/j8CMgjiyhR5uKnlaUgSK33PKYdI7ud3tv7fXSnpT8Np+44LwRcBs2OzF5Op3E865BjsAd3jugh++soJ692+OnQLVCADki7wxkVLVfoF61Ml4msWBs17chkL5RJsNtVlJKTmg=='}}],
#  'explanation': [{'type': 'text',
# ...

# %%
# workflow.get_state(config1)
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': [{'type': 'text', 'text': 'Why did the pasta go to the doctor?\n\nBecause it was feeling **cannelloni**.', 'extras': {'signature': 'EnEKbwERTTIPQzzKGrU5a/j8CMgjiyhR5uKnlaUgSK33PKYdI7ud3tv7fXSnpT8Np+44LwRcBs2OzF5Op3E865BjsAd3jugh++soJ692+OnQLVCADki7wxkVLVfoF61Ml4msWBs17chkL5RJsNtVlJKTmg=='}}], 'explanation': [{'type': 'text', 'text': 'This joke is a pun based on the phonetic similarity between a type of pasta and a common English phrase.\n\nHere is the breakdown:\n\n1.  **The Pasta:** **Cannelloni** is a type of Italian pasta consisting of cylindrical tubes, usually stuffed with a filling.\n2.  **The Phrase:** The word "cannelloni" sounds very similar to the phrase **"canonly"** (a play on the words **"can only"**).\n3.  **The Context:** When someone is feeling sick, they might say, "I\'m feeling **can only**..." (implying they are only able to do something, or are in a specific state). However, in this pun, it is meant to sound like **"
# ...

# %%
# list(workflow.get_state_history(config1))
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': [{'type': 'text', 'text': 'Why did the pasta go to the doctor?\n\nBecause it was feeling **cannelloni**.', 'extras': {'signature': 'EnEKbwERTTIPQzzKGrU5a/j8CMgjiyhR5uKnlaUgSK33PKYdI7ud3tv7fXSnpT8Np+44LwRcBs2OzF5Op3E865BjsAd3jugh++soJ692+OnQLVCADki7wxkVLVfoF61Ml4msWBs17chkL5RJsNtVlJKTmg=='}}], 'explanation': [{'type': 'text', 'text': 'This joke is a pun based on the phonetic similarity between a type of pasta and a common English phrase.\n\nHere is the breakdown:\n\n1.  **The Pasta:** **Cannelloni** is a type of Italian pasta consisting of cylindrical tubes, usually stuffed with a filling.\n2.  **The Phrase:** The word "cannelloni" sounds very similar to the phrase **"canonly"** (a play on the words **"can only"**).\n3.  **The Context:** When someone is feeling sick, they might say, "I\'m feeling **can only**..." (implying they are only able to do something, or are in a specific state). However, in this pun, it is meant to sound like **
# ...

# %% [markdown]
# ### Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f197d9e-1166-6a7d-8002-e527056962e7"}})
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': [{'type': 'text', 'text': 'Why does pizza only come in a square box?\n\nBecause it’s round, you eat it in triangles, and it’s served in a square box. \n\nIt’s the only food that’s constantly trying to confuse you!', 'extras': {'signature': 'EnEKbwERTTIPQCrMxpImwVuzVWDgsr0lqomrbNkxIMDFknWKUaRJNK9djM+XH3D/Zy1RVz+rhyX9tXtuCekT4xKwVW9Yh8x1lMwaAyrKaApjKWK3x5o/W7s9ZwrCvkmwpPAAYZdT1/kYeqA+IvSSKw+YbA=='}}], 'explanation': [{'type': 'text', 'text': 'This joke relies on the **irony and absurdity of geometric shapes** that we encounter in everyday life, specifically regarding how pizza is manufactured, packaged, and consumed.\n\nHere is the breakdown of why it is considered funny:\n\n### 1. The Geometric Incongruity\nThe humor stems from the "non-matching" shapes involved in the pizza experience:\n*   **It’s round:** Pizza is almost always baked as a circle.\n*   **You eat it in triangles:** Because of the circular shape, it is traditionally slice
# ...

# %% [markdown]
# Rerunning from that checkpoint . With None as the initial state it will resume . This helps in debugging and knowing what is happenning under the hood

# %%
workflow.invoke(None, {"configurable": {"thread_id": "2", "checkpoint_id": "1f197daa-21b6-6172-bfff-9349804615a3"}})
# Out:
# {'topic': 'pasta',
#  'joke': [{'type': 'text',
#    'text': 'Why did the pasta go to the doctor?\n\nBecause it was feeling **cannelloni**.',
#    'extras': {'signature': 'EnEKbwERTTIPxvBG+YRsKvMY193jDdsMRBqOvlGOgmXFxIu5HYrzGJUUq49Ot+36S2TN4IAde4dlPbUInfgvb51ef9Scu1UOk+9rXAmUwdNJcMhsRajnprFb1cgzWvi+RLF41c95dy9Rw7RXMxyolswLwg=='}}],
#  'explanation': [{'type': 'text',
# ...

# %% [markdown]
# As we can see the new joke is generated

# %%
list(workflow.get_state_history(config1))

# %% [markdown]
# #### Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f197d9d-ac39-6b65-bfff-c62656fd34e4", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f197dd5-9128-6735-8000-dedf086b431b'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f197dd5-9128-6735-8000-dedf086b431b'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-08-14T12:40:36.314893+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f197d9d-ac39-6b65-bfff-c62656fd34e4'}}, tasks=(PregelTask(id='954c0e76-935a-3024-6ce1-348943e5d18b', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id": "1f197dd5-9128-6735-8000-dedf086b431b"}}) # this id is of the new fork generated after updating topic to samosa
# Out:
# {'topic': 'samosa',
#  'joke': [{'type': 'text',
#    'text': 'Why did the samosa go to the doctor?\n\nBecause it was feeling a little **stuffed**, and it was worried it might have a **leaky** filling!',
#    'extras': {'signature': 'EnEKbwERTTIP1oQiCK7/4MMwkptpWj4fuE+lfAjxXg7AZtYWs6IJkpw6fROf9lldHkTq0rDw9KQuH21DdrMvUcXM9R3NTET04vOsbarxLxaSRcaSX44/iqL4Yqnn2H1WNS512KjyhhxlYPVxuRKTpGEogQ=='}}],
#  'explanation': [{'type': 'text',
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': [{'type': 'text', 'text': 'Why did the samosa go to the doctor?\n\nBecause it was feeling a little **stuffed**, and it was worried it might have a **leaky** filling!', 'extras': {'signature': 'EnEKbwERTTIP1oQiCK7/4MMwkptpWj4fuE+lfAjxXg7AZtYWs6IJkpw6fROf9lldHkTq0rDw9KQuH21DdrMvUcXM9R3NTET04vOsbarxLxaSRcaSX44/iqL4Yqnn2H1WNS512KjyhhxlYPVxuRKTpGEogQ=='}}], 'explanation': [{'type': 'text', 'text': 'This joke relies on a **pun**, which is a play on words that have double meanings. Here is the breakdown of why it’s funny:\n\n1.  **The "Stuffed" Pun:** A samosa is a pastry that is filled with a mixture (usually potatoes, peas, or meat). If you have eaten too much, you describe yourself as feeling "stuffed." In this joke, the samosa is literally "stuffed" with its filling, creating a double meaning between being full of food and being a food item itself.\n2.  **The "Leaky" Pun:** A common culinary issue with samosas is that if the dough isn\'t
# ...

# %% [markdown]
# ### Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(10)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ❌ Kernel manually interrupted (crash simulated).

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f197dc6-5313-66d2-8001-92e11f5d3fce'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-14T12:33:47.151910+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f197dc6-530f-68c4-8000-a66b224ef8f8'}}, tasks=(PregelTask(id='3ba4da2f-d3e8-9162-7e41-286cceeb1068', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %% [markdown]
# As we can see due to interruption step 2 is not executed

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}}) # this None tells to resume from the previous states
print("\n✅ Final State:", final_state)
# Out:
# 🔁 Re-running the graph to demonstrate fault tolerance...
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ✅ Step 3 executed
#
# ✅ Final State: {'input': 'start', 'step1': 'done', 'step2': 'done'}

# %% [markdown]
# We can it started from the step 2 not from the beginning. This None makes it resume from the last state interupted

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=(), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f197dc7-efa2-65e9-8003-60e49cdeb474'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-08-14T12:34:30.411808+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f197dc7-ef9f-677c-8002-b517c7f2fa87'}}, tasks=(), interrupts=()),
# ...

# %% [markdown]
# Now we can see the step2 is executed . And it is resumed not restarted from the beginning
